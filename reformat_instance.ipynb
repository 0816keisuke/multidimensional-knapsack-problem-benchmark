# %% [markdown]
# # Reformat Original MKP Benchmark
#
# Download benchmarks from:
# https://www.researchgate.net/publication/271198281_Benchmark_instances_for_the_Multidimensional_Knapsack_Problem#:~:text=The%20multidimensional%20knapsack%20problem%20is,Assimilation%20(ICAwICA)%20is%20presented.

# %%
import numpy as np
import glob
import re
import os

# %%
# Sort correctly strings with a number inside
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# %%
# Get all the instance dat-files
INSTANCE_PATH = "All-MKP-Instances/**/*.dat"
instance_list = sorted(glob.glob(INSTANCE_PATH, recursive=True), key=natural_keys)

# %%
def reformat_instance(file_path):
    with open(file_path) as f:
        line_ct = 0
        dim_i = -1
        item_ct = 0
        for line in f:
            line_array = line.split()
            if line_ct == 0:
                num_item = int(line_array[0])
                dim = int(line_array[1])
                optimum = int(line_array[2])
                value_list = np.zeros(num_item, dtype=np.int16)
                weight_list = np.zeros((dim, num_item), dtype=np.int16)
                max_weight_list = np.zeros(dim, dtype=np.int16)
                # print(f"<<< #Dim : {dim}, #item : {num_item} >>>\n")
            else:
                if dim_i == -1: # value_listへの追加(最初)
                    for i in range(len(line_array)):
                        value_list[item_ct+i] = int(line_array[i])
                    # print(f"value_list : {value_list}")

                elif dim_i < dim: # weight_listへの追加(value_listが終わったら)
                    for i in range(len(line_array)):
                        weight_list[dim_i, item_ct+i] = int(line_array[i])
                    # print(f"weight_list : {weight_list}")

                else: # max_weight_listへの追加(weight_listが終わったら)
                    for i in range(len(line_array)):
                        max_weight_list[item_ct+i] = int(line_array[i])                
                    # print(f"max_weight_list : {max_weight_list}")

                item_ct += len(line_array)
                # print(f"dim_i: {dim_i}, item_ct: {item_ct}\n")

                if item_ct == num_item:
                    item_ct = 0
                    dim_i += 1
                    # print("!!!DIMENSHION CHANGED!!!")
            line_ct += 1
    
    save_to_file(file_path, num_item, dim, optimum, value_list, weight_list, max_weight_list)

# %%
def save_to_file(file_path, num_item, dim, optimum, value_list, weight_list, max_weight_list):
    save_to_path = file_path.replace("All-MKP-Instances", "instance")
    os.makedirs(os.path.dirname(save_to_path), exist_ok=True)
    with open(save_to_path, mode="w") as f:
        f.write(f"{num_item} {dim} {optimum}\n")
        f.write(" ".join([str(n) for n in value_list])+"\n")
        for i in range(dim):
            f.write(" ".join([str(n) for n in list(weight_list[i])])+"\n")
        f.write(" ".join([str(n) for n in max_weight_list])+"\n")

# %%
# Reformat all the instances
for i in range(len(instance_list)):
    if instance_list[i] == os.path.dirname(instance_list[i]) + "/" + os.path.splitext(os.path.basename(os.path.dirname(instance_list[i])))[0] + ".dat":
        print(f"{instance_list[i]} is the summary-file. Pass.")
    else:
        print(f"Reformatting : {instance_list[i]} ...", end=" ")
        reformat_instance(instance_list[i])
        print("DONE!")
print("Reformatting is Finished!")
# Out:
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.25_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.25_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.25_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.25_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.25_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.25_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.25_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.25_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.25_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.25_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.50_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.50_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.50_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.50_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.50_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.50_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.50_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.50_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.50_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.50_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.75_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.75_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.75_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.75_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.75_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.75_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.75_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.75_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.75_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x100/OR5x100-0.75_10.dat ... DONE!
# All-MKP-Instances/chubeas/OR5x100/OR5x100.dat is the summary-file. Pass.
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.25_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.25_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.25_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.25_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.25_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.25_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.25_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.25_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.25_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.25_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.50_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.50_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.50_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.50_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.50_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.50_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.50_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.50_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.50_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.50_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.75_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.75_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.75_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.75_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.75_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.75_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.75_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.75_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.75_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x250/OR5x250-0.75_10.dat ... DONE!
# All-MKP-Instances/chubeas/OR5x250/OR5x250.dat is the summary-file. Pass.
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.25_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.25_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.25_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.25_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.25_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.25_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.25_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.25_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.25_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.25_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.50_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.50_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.50_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.50_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.50_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.50_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.50_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.50_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.50_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.50_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.75_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.75_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.75_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.75_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.75_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.75_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.75_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.75_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.75_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR5x500/OR5x500-0.75_10.dat ... DONE!
# All-MKP-Instances/chubeas/OR5x500/OR5x500.dat is the summary-file. Pass.
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.25_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.25_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.25_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.25_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.25_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.25_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.25_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.25_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.25_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.25_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.50_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.50_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.50_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.50_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.50_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.50_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.50_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.50_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.50_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.50_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.75_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.75_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.75_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.75_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.75_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.75_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.75_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.75_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.75_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x100/OR10x100-0.75_10.dat ... DONE!
# All-MKP-Instances/chubeas/OR10x100/OR10x100.dat is the summary-file. Pass.
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.25_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.25_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.25_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.25_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.25_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.25_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.25_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.25_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.25_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.25_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.50_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.50_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.50_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.50_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.50_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.50_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.50_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.50_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.50_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.50_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.75_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.75_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.75_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.75_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.75_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.75_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.75_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.75_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.75_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x250/OR10x250-0.75_10.dat ... DONE!
# All-MKP-Instances/chubeas/OR10x250/OR10x250.dat is the summary-file. Pass.
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.25_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.25_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.25_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.25_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.25_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.25_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.25_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.25_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.25_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.25_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.50_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.50_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.50_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.50_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.50_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.50_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.50_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.50_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.50_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.50_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.75_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.75_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.75_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.75_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.75_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.75_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.75_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.75_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.75_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR10x500/OR10x500-0.75_10.dat ... DONE!
# All-MKP-Instances/chubeas/OR10x500/OR10x500.dat is the summary-file. Pass.
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.25_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.25_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.25_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.25_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.25_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.25_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.25_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.25_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.25_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.25_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.50_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.50_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.50_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.50_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.50_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.50_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.50_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.50_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.50_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.50_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.75_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.75_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.75_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.75_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.75_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.75_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.75_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.75_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.75_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x100/OR30x100-0.75_10.dat ... DONE!
# All-MKP-Instances/chubeas/OR30x100/OR30x100.dat is the summary-file. Pass.
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.25_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.25_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.25_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.25_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.25_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.25_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.25_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.25_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.25_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.25_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.50_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.50_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.50_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.50_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.50_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.50_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.50_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.50_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.50_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.50_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.75_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.75_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.75_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.75_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.75_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.75_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.75_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.75_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.75_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x250/OR30x250-0.75_10.dat ... DONE!
# All-MKP-Instances/chubeas/OR30x250/OR30x250.dat is the summary-file. Pass.
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.25_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.25_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.25_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.25_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.25_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.25_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.25_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.25_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.25_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.25_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.50_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.50_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.50_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.50_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.50_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.50_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.50_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.50_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.50_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.50_10.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.75_1.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.75_2.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.75_3.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.75_4.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.75_5.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.75_6.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.75_7.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.75_8.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.75_9.dat ... DONE!
# Reformatting : All-MKP-Instances/chubeas/OR30x500/OR30x500-0.75_10.dat ... DONE!
# All-MKP-Instances/chubeas/OR30x500/OR30x500.dat is the summary-file. Pass.
# Reformatting : All-MKP-Instances/gk/gk01.dat ... DONE!
# Reformatting : All-MKP-Instances/gk/gk02.dat ... DONE!
# Reformatting : All-MKP-Instances/gk/gk03.dat ... DONE!
# Reformatting : All-MKP-Instances/gk/gk04.dat ... DONE!
# Reformatting : All-MKP-Instances/gk/gk05.dat ... DONE!
# Reformatting : All-MKP-Instances/gk/gk06.dat ... DONE!
# Reformatting : All-MKP-Instances/gk/gk07.dat ... DONE!
# Reformatting : All-MKP-Instances/gk/gk08.dat ... DONE!
# Reformatting : All-MKP-Instances/gk/gk09.dat ... DONE!
# Reformatting : All-MKP-Instances/gk/gk10.dat ... DONE!
# Reformatting : All-MKP-Instances/gk/gk11.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/hp/hp1.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/hp/hp2.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/pb/pb1.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/pb/pb2.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/pb/pb4.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/pb/pb5.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/pb/pb6.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/pb/pb7.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/pet/pet2.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/pet/pet3.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/pet/pet4.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/pet/pet5.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/pet/pet6.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/pet/pet7.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/sento/sento1.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/sento/sento2.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weing/weing1.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weing/weing2.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weing/weing3.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weing/weing4.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weing/weing5.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weing/weing6.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weing/weing7.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weing/weing8.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish01.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish02.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish03.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish04.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish05.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish06.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish07.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish08.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish09.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish10.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish11.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish12.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish13.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish14.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish15.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish16.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish17.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish18.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish19.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish20.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish21.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish22.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish23.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish24.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish25.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish26.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish27.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish28.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish29.dat ... DONE!
# Reformatting : All-MKP-Instances/sac94/weish/weish30.dat ... DONE!
# Reformatting is Finished!
